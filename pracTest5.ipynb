# %%
# Student Name: Mugdha Chakma
# Student ID  : 22122847

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load in the CSV data from one of the sweep runs
df = pd.read_csv('test5sweep2024-10-16_10.01.46/SIR_Model_r_0.0020_a_0.4.csv')

# %%
# Plot the data
plt.plot(df['Scur'], label="S")
plt.plot(df['Rcur'], label="R")
plt.plot(df['Icur'], label="I")
plt.show()
